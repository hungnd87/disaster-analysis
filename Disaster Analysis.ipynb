# %%
from price_resource import load_price, load_price_to_2020, load_price_ochlv, load_price_to_2020
from app_const import vn30
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
disaster_begin_date = '2020-01-20'
disaster_end_date = '2020-03-15'

# %% [markdown]
# # Tình hình VN30 2020

# %%
fig = go.Figure()
for symbol in vn30:
    df = load_price_ochlv(symbol, 2020)
    df.head()
    fig.add_trace(go.Scatter(
                x=df.date_time,
                y=df['close'],
                name=symbol,
                opacity=0.8))
    fig.update_layout(xaxis_range=[disaster_begin_date,disaster_end_date],
                  title_text="Manually Set Date Range")
    #fig = px.line(df, x="date_time", y="close", title='Price of VIC')
fig.show()
# Out:
# <div>
#
#
#             <div id="a9ad59da-6d52-48f5-9e6a-7655dbfb6d0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a9ad59da-6d52-48f5-9e6a-7655dbfb6d0c")) {
#                     Plotly.newPlot(
#                         'a9ad59da-6d52-48f5-9e6a-7655dbfb6d0c',
# ...

# %%
df_from_
